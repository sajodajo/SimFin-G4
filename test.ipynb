# %%
from pySimFinLib import pySimFin

# %%
psfObj = pySimFin()

# %%
psfObj.get_share_prices(tickers=['MSFT','AAPL'],start='2024-01-02',end='2024-01-05')
# Out:
# Tickers: ['MSFT', 'AAPL'], Type: <class 'list'>
# Dataset "us-shareprices-daily" on disk (0 days old).
# - Loading from disk ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/simfin/load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
#                    SimFinId    Open    High     Low   Close  Adj. Close  \
# Ticker Date
# AAPL   2024-01-02    111052  187.15  188.44  183.88  185.64      184.53
#        2024-01-03    111052  184.22  185.88  183.43  184.25      183.15
#        2024-01-04    111052  182.15  183.09  180.88  181.91      180.83
#        2024-01-05    111052  181.99  182.76  180.17  181.18      180.10
# MSFT   2024-01-02     59265  373.86  375.90  366.77  370.87      367.41
# ...

# %%
psfObj.get_financial_statement(tickers=['MSFT','AAPL'],start='2023-01-02',end='2025-01-05',period='quarterly')
# Out:
# Dataset "us-income-quarterly" on disk (0 days old).
# - Loading from disk ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/simfin/load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# MSFT   2023-03-31      59265      USD         2023            Q3   2023-04-25
#        2023-06-30      59265      USD         2023            Q4   2023-07-27
#        2023-09-30      59265      USD         2024            Q1   2023-10-24
#        2023-12-31      59265      USD         2024            Q2   2024-01-30
# AAPL   2023-03-31     111052      USD         2023            Q2   2023-05-05
# ...
