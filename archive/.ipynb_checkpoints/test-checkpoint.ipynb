# %%
from dateutil import parser
from pySimFinLib import pySimFin 

tickerList = 'AAPL'
dateStart = '2022-01-01'
dateEnd = '2022-06-01'

psfObj = pySimFin()
psfObj.get_share_prices(tickers=tickerList,start=dateStart,end=dateEnd)
psfObj.get_financial_statement(tickers= tickerList,start=dateStart,end=dateEnd,period='quarterly')
# Out:
# Dataset "us-shareprices-daily" on disk (0 days old).
# - Loading from disk ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/simfin/load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
# Dataset "us-income-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/simfin/load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# AAPL   2022-03-31     111052      USD         2022            Q2   2022-04-29
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# AAPL   2022-03-31     2023-05-05    1.639172e+10      1.651929e+10
#
#                          Revenue  Cost of Revenue  ...  \
# Ticker Report Date                                 ...
# AAPL   2022-03-31   9.727800e+10    -5.471900e+10  ...
#
#                     Non-Operating Income (Loss)  Interest Expense, Net  \
# Ticker Report Date
# AAPL   2022-03-31                   160000000.0              9019073.0
#
#                     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# Ticker Report Date
# AAPL   2022-03-31                 3.013900e+10                      NaN
#
#                     Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# Ticker Report Date
# AAPL   2022-03-31            30139000000                      -5.129000e+09
#
#                     Income (Loss) from Continuing Operations  \
# Ticker Report Date
# AAPL   2022-03-31                                25010000000
#
#                     Net Extraordinary Gains (Losses)   Net Income  \
# Ticker Report Date
# AAPL   2022-03-31                                NaN  25010000000
#
#                     Net Income (Common)
# Ticker Report Date
# AAPL   2022-03-31           25010000000
#
# [1 rows x 26 columns]
